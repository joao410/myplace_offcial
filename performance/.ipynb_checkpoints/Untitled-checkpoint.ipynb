# %%
 import fdb
 import pandas as pd
 from users.models import UsuarioCorporativo 
 con = fdb.connect(dsn='arena/3050:C:\CICOM\MECAUTO\DB\CICOM.CDB', user='SYSDBA', password='masterkey')
 cur = con.cursor()
 SELECT = "SELECT * FROM TAB_CAD_FUN"
 cur.execute(SELECT)
 rows = cur.fetchall()
 prof = pd.DataFrame(rows)
 headers = [i[0] for i in cur.description]
 prof.columns = headers


prof
# Out:
#      CM_COD_FUN  CM_NAS_FUN  CM_DAT_ADM  CM_DAT_DEM  \
# 0             1  1987-06-22  2008-09-01  2009-04-13
# 1             2  1899-12-30  2009-10-02  2010-03-27
# 2             3  1976-06-15  2008-07-26  2016-06-25
# 3             4  1990-08-07  2008-05-01  2009-05-18
# 4             5  1975-12-28  2009-03-16  2009-09-20
# ..          ...         ...         ...         ...
# 826         827  2003-03-22  2021-09-08        None
# 827         829  2001-03-31  2021-10-11        None
# 828         828  1977-03-27  2021-09-21        None
# 829         830  1996-05-01  2021-10-04        None
# 830         831  1995-04-15  2021-10-14        None
#
#                                       CM_NOM_FUN        CM_APL_FUN  \
# 0                                   FELIPE CARLI                DI
# 1                                         FELIPE         FELIPE II
# 2                            JOSE FERNANDO FILHO             SAURO
# 3                      JHONATAN CORELIANO SOARES          JHONATAN
# 4                                           None             HONDA
# ..                                           ...               ...
# 826                      NICOLAS GOMES CONCEIÇÃO               NIC
# 827           ISABELA VIANA DO NASCIMENTO AMARAL    ISABELA AMARAL
# 828                       FABIO MARINHO DA SILVA           MARINHO
# 829          MURILO ALCÂNTARA DE OLIVEIRA SANTOS  MURILO ALCANTÂRA
# 830  LARISSA CAROLINE MORENO DE OLIVEIRA PEREIRA           LARISSA
#
#                              CM_END_FUN        CM_BAI_FUN   CM_CID_FUN  \
# 0       AV. PADRE VICENTE MELILLO, 1052      JD. ORIENTAL       OSASCO
# 1                                  None              None       OSASCO
# 2                                    ,       VILA PESTANA       OSASCO
# 3                         RUA ITAU, 01               None  CARAPICUIBA
# 4    RUA JOAO CABRAL DE MELLO NETO, 114              None       OSASCO
# ..                                  ...               ...          ...
# 826   Viela Gentil Xavier de Paula, 366      JARDIM ESTER       Osasco
# 827                 R LAURO FREIRE, 428    JARDIM CELESTE    São Paulo
# 828                     R PATRIOTAS, 90      VILA LOURDES  Carapicuíba
# 829                    R FELGUEIRAS, 98  JARDIM MITSUTANI    São Paulo
# 830    AV MARECHAL FIUZA DE CASTRO, 340  JARDIM PINHEIROS    São Paulo
#
#     CM_UF_FUN  ... CM_MOT_TRAB_TEMP CM_CPF_TRAB_SUBST CM_MATRICULA_SUBST  \
# 0          SP  ...             None              None               None
# 1          SP  ...             None              None               None
# 2          SP  ...             None              None               None
# 3          SP  ...             None              None               None
# 4          SP  ...             None              None               None
# ..        ...  ...              ...               ...                ...
# 826        SP  ...             None              None               None
# 827        SP  ...             None              None               None
# 828        SP  ...             None              None               None
# 829        SP  ...             None              None               None
# 830        SP  ...             None              None               None
#
#     CM_TIP_INSCR_LOCAL CM_NUM_INSCR_LOCAL CM_COD_LOTACAO_LOCAL  \
# 0                 None               None                 None
# 1                 None               None                 None
# 2                 None               None                 None
# 3                 None               None                 None
# 4                 None               None                 None
# ..                 ...                ...                  ...
# 826               None               None                 None
# 827               None               None                 None
# 828               None               None                 None
# 829               None               None                 None
# 830               None               None                 None
#
#     CM_DESCR_COMPL_LOCAL CM_GER_ENT_VND                       CM_URL_FOTO  \
# 0                   None              N  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 1                   None              N  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 2                   None              N  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 3                   None              N  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 4                   None              N  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# ..                   ...            ...                               ...
# 826                 None           None  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 827                 None           None  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 828                 None           None  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 829                 None           None  ~\FOTO\SEM_FOTO_PARTICIPANTE.PNG
# 830                 None              N    ~\FOTO\39535334875LARISSA.jpeg
#
#     CM_ST
# 0       N
# 1       N
# 2       N
# 3       N
# 4       N
# ..    ...
# 826     N
# 827     N
# 828     N
# 829     N
# 830     N
#
# [831 rows x 103 columns]
